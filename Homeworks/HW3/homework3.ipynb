# %% [markdown]
# # Homework 3 - Using DP for object reconstruction from shadows
#
# In this homework we use mitsuba studio 3 (3.6.4), with python 3.12.

# %%
import mitsuba as mi
import os
import drjit as dr
import numpy as np
from tqdm import tqdm

# See the variants available on the Mac M3 Pro
mi.variants()
# Out:
# ['scalar_rgb',
#  'scalar_spectral',
#  'scalar_spectral_polarized',
#  'llvm_ad_rgb',
#  'llvm_ad_mono',
#  'llvm_ad_mono_polarized',
#  'llvm_ad_spectral',
#  'llvm_ad_spectral_polarized']

# %%
# We set the LLVM AutoDiff - MacOS
mi.set_variant('llvm_ad_rgb')

# %% [markdown]
# We open a 3D scene in Mitsuba XML format and render it.

# %%
# This is some macos specific - DRJIT LLVM lib path, which needs to be exported
os.environ['DRJIT_LIBLLVM_PATH'] = '/opt/homebrew/opt/llvm/lib/libLLVM.dylib'

sphere_scene = mi.load_file('sphere-scene.xml')
sphere_img = mi.render(sphere_scene, spp=16)

# %% [markdown]
# We can view the image with the Bitmap class

# %%
mi.util.convert_to_bitmap(sphere_img)
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = uint8,
#   size = [900, 800],
#   srgb_gamma = 1,
#   struct = Struct<3>[
#     uint8 R; // @0, normalized, gamma, premultiplied alpha
#     uint8 G; // @1, normalized, gamma, premultiplied alpha
#     uint8 B; // @2, normalized, gamma, premultiplied alpha
#   ],
#   data = [ 2.06 MiB of image data ]
# ]

# %% [markdown]
# We also open our reference scene

# %%
cube_scene = mi.load_file('cube-scene.xml')
cube_img = mi.render(cube_scene, spp=16)

mi.util.convert_to_bitmap(cube_img)
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = uint8,
#   size = [900, 800],
#   srgb_gamma = 1,
#   struct = Struct<3>[
#     uint8 R; // @0, normalized, gamma, premultiplied alpha
#     uint8 G; // @1, normalized, gamma, premultiplied alpha
#     uint8 B; // @2, normalized, gamma, premultiplied alpha
#   ],
#   data = [ 2.06 MiB of image data ]
# ]

# %% [markdown]
# We can traverse our scene to find the shadow object cast on the wall, this is the object against which we will optimize.

# %%
params = mi.traverse(sphere_scene)
print(params)
# Out:
# SceneParameters[
#   --------------------------------------------------------------------------------------------
#   Name                                     Flags    Type           Parent
#   --------------------------------------------------------------------------------------------
#   default-bsdf.brdf_0.reflectance.value    ∂        Float          UniformSpectrum
#   elm__1.near_clip                                  float          PerspectiveCamera
#   elm__1.far_clip                                   float          PerspectiveCamera
#   elm__1.shutter_open                               float          PerspectiveCamera
#   elm__1.shutter_open_time                          float          PerspectiveCamera
#   elm__1.film.size                                  ScalarVector2u HDRFilm
#   elm__1.film.crop_size                             ScalarVector2u HDRFilm
#   elm__1.film.crop_offset                           ScalarPoint2u  HDRFilm
#   elm__1.x_fov                             ∂, D     Float          PerspectiveCamera
#   elm__1.principal_point_offset_x          ∂, D     Float          PerspectiveCamera
#   elm__1.principal_point_offset_y          ∂, D     Float          PerspectiveCamera
#   elm__1.to_world                          ∂, D     Transform4f    PerspectiveCamera
#   elm__3.silhouette_sampling_weight                 float          PLYMesh
#   elm__3.faces                                      UInt           PLYMesh
#   elm__3.vertex_positions                  ∂, D     Float          PLYMesh
#   elm__3.vertex_normals                    ∂, D     Float          PLYMesh
#   elm__3.vertex_texcoords                  ∂        Float          PLYMesh
#   elm__4.silhouette_sampling_weight                 float          PLYMesh
#   elm__4.faces                                      UInt           PLYMesh
#   elm__4.vertex_positions                  ∂, D     Float          PLYMesh
#   elm__4.vertex_normals                    ∂, D     Float          PLYMesh
#   elm__4.vertex_texcoords                  ∂        Float          PLYMesh
#   elm__5.silhouette_sampling_weight                 float          PLYMesh
#   elm__5.faces                                      UInt           PLYMesh
#   elm__5.vertex_positions                  ∂, D     Float          PLYMesh
#   elm__5.vertex_normals                    ∂, D     Float          PLYMesh
#   elm__5.vertex_texcoords                  ∂        Float          PLYMesh
#   light2.bsdf.reflectance.value            ∂        Float          UniformSpectrum
#   light2.emitter.sampling_weight                    float          AreaLight
#   light2.emitter.radiance.value            ∂        Color3f        SRGBReflectanceSpectrum
#   light2.silhouette_sampling_weight                 float          Rectangle
#   light2.to_world                          ∂, D     Transform4f    Rectangle
#   sphere.silhouette_sampling_weight                 float          PLYMesh
#   sphere.faces                                      UInt           PLYMesh
#   sphere.vertex_positions                  ∂, D     Float          PLYMesh
#   sphere.vertex_normals                    ∂, D     Float          PLYMesh
#   sphere.vertex_texcoords                  ∂        Float          PLYMesh
# ]

# %%
# Get the shadows from setting up the sensors in the correct spots
dist = 5
sensor = mi.load_dict({
    'type': 'perspective',
    'id': 'sphere_shadow_sensor',
    'fov_axis': 'x',
    'fov': 115,
    'principal_point_offset_x': 0.0,
    'principal_point_offset_y': 0.0,
    'near_clip': 0.1,
    'far_clip': 900.0,
    'to_world': mi.ScalarTransform4f().rotate(mi.ScalarPoint3f(1, 0, 0), 179)
                                    .rotate(mi.ScalarPoint3f(0, 1, 0), 0)
                                    .rotate(mi.ScalarPoint3f(0, 0, 1), 180) @
                mi.ScalarTransform4f().translate(mi.ScalarPoint3f(0.0, 1.833394, 0.182561)),
    'sampler': {
        'type': 'independent',
        'sample_count': 16
    },
    'film': {
        'type': 'hdrfilm',
        'sample_border': True,
        'width': 700,
        'height': 600
    }
})

# %%
image_sphere_shadow = mi.render(sphere_scene, sensor=sensor, spp=64)
mi.Bitmap(image_sphere_shadow)
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = float32,
#   size = [700, 600],
#   srgb_gamma = 0,
#   struct = Struct<12>[
#     float32 R; // @0, premultiplied alpha
#     float32 G; // @4, premultiplied alpha
#     float32 B; // @8, premultiplied alpha
#   ],
#   data = [ 4.81 MiB of image data ]
# ]

# %%
image_cube_shadow = mi.render(cube_scene, sensor=sensor, spp=64)
bitmap_ref = mi.Bitmap(image_cube_shadow)
bitmap_ref
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = float32,
#   size = [700, 600],
#   srgb_gamma = 0,
#   struct = Struct<12>[
#     float32 R; // @0, premultiplied alpha
#     float32 G; // @4, premultiplied alpha
#     float32 B; // @8, premultiplied alpha
#   ],
#   data = [ 4.81 MiB of image data ]
# ]

# %% [markdown]
# We now set up the optimizer and the optimization loop

# %%
params.keep(['sphere.vertex_positions', 'sphere.faces'])

integrator = mi.load_dict({
    'type': 'direct_projective',
    'sppi': 1024,
    'sppc': 0,
    'sppp': 0,
})

lambda_ = 25
ls = mi.ad.LargeSteps(params['sphere.vertex_positions'], params['sphere.faces'], lambda_)

opt = mi.ad.Adam(lr=1e-1, uniform=True)
opt['u'] = ls.to_differential(params['sphere.vertex_positions'])

# Optimization loop
for i in tqdm(range(10)):
    params['sphere.vertex_positions'] = ls.from_differential(opt['u'])
    params.update()
    
    sphere_shadow = mi.render(sphere_scene, params=params, sensor=sensor, integrator=integrator, spp=16, seed=i)
    
    loss = dr.mean(dr.square(sphere_shadow - image_cube_shadow))
    dr.backward(loss)

    opt.step()
    
    if i % 10 == 0:
        mi.util.write_bitmap(f"progress_{i:04d}.png", sphere_shadow)

final_sphere_img = mi.render(sphere_scene, params=params, spp=256)
mi.util.write_bitmap("final_optimized.png", final_sphere_img)

final_diff = dr.abs(final_sphere_img - mi.render(cube_scene, spp=256))
mi.util.write_bitmap("final_difference.png", final_diff)
# Out:
#   2%|▏         | 3/200 [01:02<1:02:55, 19.17s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:23:53 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:23:53 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:23:53 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#   2%|▏         | 4/200 [01:17<57:25, 17.58s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:24:08 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:24:08 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:24:08 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#   4%|▎         | 7/200 [02:02<50:37, 15.74s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:24:53 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:24:53 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:24:53 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#   6%|▌         | 12/200 [03:18<47:38, 15.21s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:26:08 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:26:08 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:26:08 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#   9%|▉         | 18/200 [04:47<45:20, 14.95s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:27:38 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:27:38 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:27:38 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#  12%|█▏        | 23/200 [06:02<44:14, 14.99s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:28:53 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:28:53 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:28:53 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#  14%|█▍        | 29/200 [07:31<41:53, 14.70s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:30:21 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:30:21 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:30:21 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#  15%|█▌        | 30/200 [07:45<40:58, 14.46s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:30:35 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:30:35 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:30:35 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#  16%|█▌        | 32/200 [08:13<40:13, 14.37s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:31:03 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:31:03 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:31:03 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#  18%|█▊        | 35/200 [08:55<39:02, 14.20s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:31:45 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:31:45 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:31:45 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#  26%|██▌       | 51/200 [14:35<40:52, 16.46s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:37:26 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:37:26 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:37:26 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#  26%|██▋       | 53/200 [15:03<37:18, 15.23s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:37:53 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:37:53 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:37:53 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#  28%|██▊       | 56/200 [15:45<34:27, 14.36s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:38:35 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:38:35 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:38:35 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#  28%|██▊       | 57/200 [15:58<33:38, 14.12s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:38:48 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:38:48 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:38:48 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#  30%|██▉       | 59/200 [16:26<32:50, 13.97s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:39:16 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:39:16 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:39:16 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#  34%|███▍      | 69/200 [18:48<31:24, 14.39s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 20:56:52 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 20:56:52 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 20:56:52 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#  40%|███▉      | 79/200 [50:21<1:21:17, 40.31s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 21:13:11 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 21:13:11 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 21:13:11 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#  48%|████▊     | 97/200 [1:00:08<2:14:14, 78.20s/it]
# <span style="font-family: monospace; color: #f55">2025-03-30 21:22:59 WARN  main  [projective.py:510] init_indirect_silhouette_octree(): Failed to build the Octree guiding distribution! No guiding distibution for indirect visibility discontinuities will be used.
# 2025-03-30 21:22:59 WARN  main  [projective.py:510] The original error message from the octree construction:
# 2025-03-30 21:22:59 WARN  main  [projective.py:510] ​[distr_1d.h:220] DiscreteDistribution: empty distribution!</span>
#  50%|█████     | 100/200 [1:01:09<1:01:09, 36.69s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 24
#      21 sphere_shadow = mi.render(sphere_scene, params=params, sensor=sensor, integrator=integrator, spp=16, seed=i)
#      23 loss = dr.mean(dr.square(sphere_shadow - image_cube_shadow))
# ---> 24 dr.backward(loss)
#      26 opt.step()
#      28 if i % 10 == 0:
#
# File /opt/anaconda3/envs/mitsuba-studio/lib/python3.12/site-packages/mitsuba/python/util.py:372, in _RenderOp.backward(self)
#     371 def backward(self):
# --> 372     self.integrator.render_backward(self.scene, self.params, self.grad_out(),
#     373                                     self.sensor, self.seed[1], self.spp[1])
#
# File /opt/anaconda3/envs/mitsuba-studio/lib/python3.12/site-packages/mitsuba/python/ad/integrators/common.py:1066, in PSIntegrator.render_backward(self, scene, params, grad_in, sensor, seed, spp)
#    1061 # Discontinuous derivative (and the non-RB continuous derivative)
#    1062 if sppp > 0 or sppi > 0 or \
#    1063    (sppc > 0 and not self.radiative_backprop):
#    1064
#    1065     # Compute an image with all derivatives attached
# -> 1066     ad_img = self.render_ad(
#    1067         scene, sensor, seed, spp, dr.ADMode.Backward)
#    1069     dr.set_grad(ad_img, grad_in)
#    1070     dr.enqueue(dr.ADMode.Backward, ad_img)
#
# File /opt/anaconda3/envs/mitsuba-studio/lib/python3.12/site-packages/mitsuba/python/ad/integrators/common.py:957, in PSIntegrator.render_ad(self, scene, sensor, seed, spp, mode)
#     955 if sppi > 0 and has_silhouettes:
#     956     with dr.suspend_grad():
# --> 957         self.proj_detail.init_indirect_silhouette(scene, sensor, 0xafafafaf ^ seed)
#     959     sampler, spp = self.prepare(sensor, 0xaa00aa00 ^ seed, sppi, aovs)
#     960     result_img += self.render_indirect_silhouette(scene, sensor, sampler, spp)
#
# File /opt/anaconda3/envs/mitsuba-studio/lib/python3.12/site-packages/mitsuba/python/ad/projective.py:270, in ProjectiveDetail.init_indirect_silhouette(self, scene, sensor, seed)
#     267     self.init_indirect_silhouette_grid_proj(scene, sensor, seed)
#     269 elif parent.guiding == 'octree':
# --> 270     self.init_indirect_silhouette_octree(scene, sensor, seed)
#
# File /opt/anaconda3/envs/mitsuba-studio/lib/python3.12/site-packages/mitsuba/python/ad/projective.py:508, in ProjectiveDetail.init_indirect_silhouette_octree(self, scene, sensor, seed)
#     505 self.guiding_distr.mass_contruction_thres = parent.octree_contruction_thres
#     507 try:
# --> 508     self.guiding_distr.set_points(sample_3, value, seed, mi.log_level() == mi.LogLevel.Debug)
#     509 except Exception as e:
#     510     mi.Log(mi.LogLevel.Warn,
#     511            "Failed to build the Octree guiding distribution! No "
#     512            "guiding distibution for indirect visibility "
#     513            "discontinuities will be used.\n"
#     514            "The original error message from the octree construction:\n"
#     515            f"{e}")
#
# File /opt/anaconda3/envs/mitsuba-studio/lib/python3.12/site-packages/mitsuba/python/ad/guiding.py:503, in OcSpaceDistr.set_points(***failed resolving arguments***)
#     492     raise RuntimeError(
#     493         "No non-zero mass points remain after applying the threshold! "
#     494         "The octree construction is interrupted. Please increase "
#     495         "`mass_contruction_thres` or provide more input points to "
#     496         "solve this problem."
#     497     )
#     499 #######################
#     500 # Octree construction #
#     501 #######################
# --> 503 lower, upper = self.construct_octree(filtered_points, log=log)
#     505 ######################################################
#     506 # Additional sampling per leaf (1D PMF construction) #
#     507 ######################################################
#     509 query_mass = self.estimate_mass_in_leaves(lower, upper, seed, log=log)
#
# File /opt/anaconda3/envs/mitsuba-studio/lib/python3.12/site-packages/mitsuba/python/ad/guiding.py:373, in OcSpaceDistr.construct_octree(self, points, log)
#     369 ###########################
#     370 # Early exit & evaluation #
#     371 ###########################
#     372 dr.eval(aabb_buffer, aabb_buffer_next, points_idx, leaves, active, leaves_count)
# --> 373 leaves_count_scalar = dr.slice(leaves_count)
#     375 if self.debug_logs:
#     376     mi.Log(mi.LogLevel.Debug,
#     377            f"l{loop_iter:2d}: ttl_leaf = {leaves_count_scalar:6d}, "
#     378            f"N_leaf_new = {new_leaf_count_scalar:6d}, N_node_new = "
#     379            f"{new_active_node_count_scalar:6d}")
#
# KeyboardInterrupt:

# %%
print(params['sphere.vertex_positions'])
# Out:
# [-0.00672302, 1.9716, -0.0378031, .. 26409 skipped .., -0.0109039, 1.97155, -0.0432505]
